# %%
from utils import Chain_detect
import pandas as pd
import math

# %%
TB = pd.read_csv("csv/20210712-C0147-WASH_backgroud-5th-29C_6d_Trim.mp4.csv", sep=" ", header = None)
TB = TB[TB[0]==2417]
Chain_detect.Chain_finder(TB)

# %%
Flies = [[TB.iloc[i, 2], TB.iloc[i,3]] for i in range(len(TB))]
for i in Flies:
            for ii in Flies:
                print(i, ii)
# Out:
# [0.3169270753860473, 0.4518518447875976] [0.3169270753860473, 0.4518518447875976]
# [0.3169270753860473, 0.4518518447875976] [0.3781250119209289, 0.3921296298503876]
# [0.3169270753860473, 0.4518518447875976] [0.44140625, 0.3620370328426361]
# [0.3169270753860473, 0.4518518447875976] [0.6208333373069763, 0.7773148417472839]
# [0.3169270753860473, 0.4518518447875976] [0.3179687559604645, 0.720370352268219]
# [0.3169270753860473, 0.4518518447875976] [0.2893229126930237, 0.4736111164093017]
# [0.3169270753860473, 0.4518518447875976] [0.293749988079071, 0.6393518447875977]
# [0.3169270753860473, 0.4518518447875976] [0.3192708194255829, 0.7300925850868225]
# [0.3169270753860473, 0.4518518447875976] [0.2919270694255829, 0.6458333134651184]
# [0.3169270753860473, 0.4518518447875976] [0.30859375, 0.697685182094574]
# [0.3169270753860473, 0.4518518447875976] [0.504687488079071, 0.864814817905426]
# [0.3169270753860473, 0.4518518447875976] [0.3283854126930237, 0.4601851999759674]
# ...

# %%
math.sqrt((i[0]-ii[0])^2 + (i[1]+ ii[1])^2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26657/520049430.py in <module>
# ----> 1 math.sqrt((i[0]-ii[0])^2 + (i[1]+ ii[1])^2)
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
2**2
# Out:
# 4
